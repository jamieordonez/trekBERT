# %%
import pandas as pd
import re
import os

def clean_star_trek_script(csv_df):
    # Step 1: Remove rows where Dialogue is missing
    df_cleaned = csv_df.dropna(subset=['Dialogue']).copy()
    
    # Step 2: Fill missing Character names with 'Unknown'
    df_cleaned['Character'] = df_cleaned['Character'].fillna('Unknown')
    
    # Step 3: Remove rows that primarily contain metadata in the Dialogue field
    # Assuming metadata usually doesn't have speaking characters associated with it
    df_cleaned = df_cleaned[df_cleaned['Character'] != 'Unknown']
    
    # Step 4: Define a text-cleaning function
    def clean_text(text):
        text = re.sub(r'\[.*?\]', '', text)  # Remove text within brackets
        text = re.sub(r'[^a-zA-Z0-9\s.,!?\'\"]', '', text)  # Remove special characters except basic punctuation
        text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
        return text
    
    # Apply the cleaning function to the Dialogue column
    df_cleaned['Dialogue'] = df_cleaned['Dialogue'].astype(str).apply(clean_text)
    
    # Optional: Save the cleaned data to a new CSV file
    df_cleaned.to_csv('Cleaned_Star_Trek_Script.csv', index=False)
    
    # Display the first few rows to verify the changes
    print(df_cleaned.head())
    return df_cleaned

# Define the folder path
folder_path = "/home/sagemaker-user/trekBERT/Movies.csv"
save_cleaned = True  # Ensure this variable is defined

# Process files
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        print(f'Processing file: {filename}')
        
        # Read the CSV file into a DataFrame
        csv_df = pd.read_csv(file_path)  # FIX: Load CSV into DataFrame before passing it
        
        # Clean the scripts
        cleaned_df = clean_star_trek_script(csv_df)
        
        # Save cleaned dfs
        if save_cleaned:
            cleaned_file_path = os.path.join(folder_path, f"cleaned_{filename}")
            cleaned_df.to_csv(cleaned_file_path, index=False)
            print(f"Saved cleaned file to: {cleaned_file_path}")

print("All files processed.")
# Out:
# Processing file: Star_Trek_Final_Frontier_Script.csv
#     Scene_ID    Character                                           Dialogue  \
# 0        0.0  Star Trek V                                 The Final Frontier
# 8        0.0        SYBOK  I thought weapons were forbidden on this plane...
# 9        0.0        J'ONN                                   It's all I have.
# 10       0.0        SYBOK                               Your pain runs deep.
# 11       0.0        J'ONN                       What do you know of my pain?
#
#    Scene_Description                                           Metadata
# 0                NaN                                                NaN
# 8                NaN                     "The Planet of Galactic Peace"
# 9                NaN  (out of a dust storm a horseman approaches an ...
# 10               NaN                                                NaN
# 11               NaN                                                NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Final_Frontier_Script.csv
# Processing file: Star_Trek_First_Contact_Script.csv
#     Scene_ID          Character  \
# 0        0.0          Star Trek
# 6        1.0    BORG QUEEN (OC)
# 7        1.0             PICARD
# 9        1.0             PICARD
# 10       1.0  HAYES (on viewer)
#
#                                              Dialogue    Scene_Description  \
# 0                                       First Contact                  NaN
# 6                                            Locutus.  [Picard's quarters]
# 7         I am Locutus of Borg. Resistance is futile.  [Picard's quarters]
# 9   Authorisation Picard four seven alpha tango. ....  [Picard's quarters]
# 10             Did I catch you at a bad time JeanLuc?  [Picard's quarters]
#
#                                              Metadata
# 0                                                 NaN
# 6                                                 NaN
# 7   (Picard is having a dream about his memories f...
# 9                                                 NaN
# 10  (he is awakened by a comm bleep just as he is ...
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_First_Contact_Script.csv
# Processing file: Star_Trek_Generations_Script.csv
#     Scene_ID      Character  \
# 7        1.0  JOURNALIST #3
# 8        1.0       HARRIMAN
# 9        1.0           KIRK
# 10       1.0       HARRIMAN
# 11       1.0           KIRK
#
#                                              Dialogue      Scene_Description  \
# 7   Captain Kirk, how does it feel to be back on t...  [Enterprise-B bridge]
# 8   Excuse me, excuse me, excuse me. There will be...  [Enterprise-B bridge]
# 9                                  It's our pleasure.  [Enterprise-B bridge]
# 10  I just want you to know how excited we all are...  [Enterprise-B bridge]
# 11    Oh, really. Well, ...may we have a look around?  [Enterprise-B bridge]
#
#    Metadata
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Generations_Script.csv
# Processing file: Star_Trek_Insurrection_Script.csv
#    Scene_ID                  Character  \
# 0       0.0                  Star Trek
# 5       1.0                BA'KU CHILD
# 7       2.0           SO'NA COMM VOICE
# 8       2.0  STARFLEET OFFICER #1 (OC)
# 9       2.0           SO'NA COMM VOICE
#
#                                           Dialogue          Scene_Description  \
# 0                                     Insurrection                        NaN
# 5                      There he is. Let's get him.   [Ba'ku village hayfield]
# 7                           Area seven to command.  [Duck blind control room]
# 8                                        Go ahead.  [Duck blind control room]
# 9  We could use another survey team out here, sir.  [Duck blind control room]
#
#   Metadata
# 0      NaN
# 5      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Insurrection_Script.csv
# Processing file: Star_Trek_Nemesis_Script.csv
#     Scene_ID     Character                                           Dialogue  \
# 5        1.0    SURAN (OC)  Senators, consider the opportunities for the E...
# 7        2.0         SURAN  ...than ever before. It would be madness to re...
# 8        2.0         HIREN  That's enough! The decision has been made. The...
# 10       2.0         HIREN  The Senate has considered Shinzon's proposal a...
# 11       2.0  COMMANDER #2                                           Yes sir.
#
#             Scene_Description  \
# 5   [Romulan Senate building]
# 7    [Romulan Senate chamber]
# 8    [Romulan Senate chamber]
# 10   [Romulan Senate chamber]
# 11   [Romulan Senate chamber]
#
#                                              Metadata
# 5                             ROMULAN IMPERIAL SENATE
# 7                                                 NaN
# 8                                                 NaN
# 10                                                NaN
# 11  (a female senator, Tal'aura, looks down at a r...
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Nemesis_Script.csv
# Processing file: Star_Trek_Script.csv
#     Scene_ID        Character  \
# 0        0.0        Star Trek
# 7        1.0  KLINGON CAPTAIN
# 9        1.0  KLINGON CAPTAIN
# 11       1.0  KLINGON CAPTAIN
# 13       1.0  KLINGON CAPTAIN
#
#                                              Dialogue Scene_Description  \
# 0                                  The Motion Picture               NaN
# 7                             In Klingonese Tactical.  [Klingon bridge]
# 9                               In Klingonese Visual.  [Klingon bridge]
# 11  In Klingonese Tactical. Stand by on torpedoes....  [Klingon bridge]
# 13                             In Klingonese Evasive!  [Klingon bridge]
#
#                                              Metadata
# 0                                                 NaN
# 7   (three Klingon battle cruisers approach a lumi...
# 9                                                 NaN
# 11                                                NaN
# 13                                                NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Script.csv
# Processing file: Star_Trek_Search_for_Spock_Script.csv
#    Scene_ID                              Character  \
# 0       0.0                          Star Trek III
# 2       0.0  (scenes from the end of "Star Trek II
# 4       1.0                                  SPOCK
# 5       1.0                                   KIRK
# 6       1.0                                  SPOCK
#
#                                             Dialogue  \
# 0                               The Search for Spock
# 2                                The Wrath of Khan."
# 4  Don't grieve, Admiral, ...it is logical. The n...
# 5                           ...the needs of the few.
# 6  Or the one. I have been ...and always shall be...
#
#           Scene_Description                        Metadata
# 0                       NaN                             NaN
# 2                       NaN  Original Airdate: Jul 27, 1984
# 4  [Enterprise engineering]                             NaN
# 5  [Enterprise engineering]                             NaN
# 6  [Enterprise engineering]                             NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Search_for_Spock_Script.csv
# Processing file: Star_Trek_Undiscovered_Country_Script.csv
#     Scene_ID     Character                                           Dialogue  \
# 0        0.0  Star Trek VI                           The Undiscovered Country
# 6        1.0          SULU  According to this we've completed our explorat...
# 8        1.0       VALTANE  I have an energy wave from two hundred and for...
# 9        1.0          SULU                     Visual! My ...God. ...Shields!
# 11       1.0    LOJUR (OC)             Captain, she's not answering her helm.
#
#      Scene_Description                                        Metadata
# 0                  NaN                                             NaN
# 6   [Excelsior bridge]  (a huge explosion spreading out through space)
# 8   [Excelsior bridge]                                             NaN
# 9   [Excelsior bridge]                                             NaN
# 11  [Excelsior bridge]                                             NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Undiscovered_Country_Script.csv
# Processing file: Star_Trek_Voyage_Home_Script.csv
#     Scene_ID                    Character  \
# 0        0.0                 Star Trek IV
# 4        0.0  (scenes from "Star Trek III
# 7        1.0                        SAREK
# 8        1.0                         KIRK
# 10       2.0                        SAREK
#
#                                              Dialogue    Scene_Description  \
# 0                                     The Voyage Home                  NaN
# 4                              The Search for Spock."                  NaN
# 7   Why did you leave him on Genesis! Spock truste...   [Kirk's apartment]
# 8                                    I saw no future.   [Kirk's apartment]
# 10  Only his body was in death, Kirk. ...bring him...  [Electronic center]
#
#                                              Metadata
# 0                                                 NaN
# 4   Captain's log, stardate 8031 in the twenty-thi...
# 7                                                 NaN
# 8                                                 NaN
# 10                                                NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Voyage_Home_Script.csv
# Processing file: Star_Trek_Wrath_of_Khan_Script.csv
#     Scene_ID     Character                                           Dialogue  \
# 0        0.0  Star Trek II                                  The Wrath of Khan
# 9        1.0          SULU      Leaving Section Fourteen for Section Fifteen.
# 10       1.0        SAAVIK  Stand by. Project parabolic course to avoid en...
# 11       1.0          SULU          Aye, Captain. ...Course change projected.
# 12       1.0         UHURA  Captain, ...I'm getting something on the distr...
#
#           Scene_Description                                           Metadata
# 0                       NaN                                                NaN
# 9   [Bridge simulator room]  Captain's log, stardate 8130.3. Starship Enter...
# 10  [Bridge simulator room]                                                NaN
# 11  [Bridge simulator room]                                                NaN
# 12  [Bridge simulator room]                                                NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_Star_Trek_Wrath_of_Khan_Script.csv
# Processing file: cleaned_Star_Trek_Final_Frontier_Script.csv
#    Scene_ID    Character                                           Dialogue  \
# 0       0.0  Star Trek V                                 The Final Frontier
# 1       0.0        SYBOK  I thought weapons were forbidden on this plane...
# 2       0.0        J'ONN                                   It's all I have.
# 3       0.0        SYBOK                               Your pain runs deep.
# 4       0.0        J'ONN                       What do you know of my pain?
#
#   Scene_Description                                           Metadata
# 0               NaN                                                NaN
# 1               NaN                     "The Planet of Galactic Peace"
# 2               NaN  (out of a dust storm a horseman approaches an ...
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_cleaned_Star_Trek_Final_Frontier_Script.csv
# Processing file: cleaned_Star_Trek_First_Contact_Script.csv
#    Scene_ID          Character  \
# 0       0.0          Star Trek
# 1       1.0    BORG QUEEN (OC)
# 2       1.0             PICARD
# 3       1.0             PICARD
# 4       1.0  HAYES (on viewer)
#
#                                             Dialogue    Scene_Description  \
# 0                                      First Contact                  NaN
# 1                                           Locutus.  [Picard's quarters]
# 2        I am Locutus of Borg. Resistance is futile.  [Picard's quarters]
# 3  Authorisation Picard four seven alpha tango. ....  [Picard's quarters]
# 4             Did I catch you at a bad time JeanLuc?  [Picard's quarters]
#
#                                             Metadata
# 0                                                NaN
# 1                                                NaN
# 2  (Picard is having a dream about his memories f...
# 3                                                NaN
# 4  (he is awakened by a comm bleep just as he is ...
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_cleaned_Star_Trek_First_Contact_Script.csv
# Processing file: cleaned_Star_Trek_Generations_Script.csv
#    Scene_ID      Character                                           Dialogue  \
# 0       1.0  JOURNALIST #3  Captain Kirk, how does it feel to be back on t...
# 1       1.0       HARRIMAN  Excuse me, excuse me, excuse me. There will be...
# 2       1.0           KIRK                                 It's our pleasure.
# 3       1.0       HARRIMAN  I just want you to know how excited we all are...
# 4       1.0           KIRK    Oh, really. Well, ...may we have a look around?
#
#        Scene_Description Metadata
# 0  [Enterprise-B bridge]      NaN
# 1  [Enterprise-B bridge]      NaN
# 2  [Enterprise-B bridge]      NaN
# 3  [Enterprise-B bridge]      NaN
# 4  [Enterprise-B bridge]      NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_cleaned_Star_Trek_Generations_Script.csv
# Processing file: cleaned_Star_Trek_Insurrection_Script.csv
#    Scene_ID                  Character  \
# 0       0.0                  Star Trek
# 1       1.0                BA'KU CHILD
# 2       2.0           SO'NA COMM VOICE
# 3       2.0  STARFLEET OFFICER #1 (OC)
# 4       2.0           SO'NA COMM VOICE
#
#                                           Dialogue          Scene_Description  \
# 0                                     Insurrection                        NaN
# 1                      There he is. Let's get him.   [Ba'ku village hayfield]
# 2                           Area seven to command.  [Duck blind control room]
# 3                                        Go ahead.  [Duck blind control room]
# 4  We could use another survey team out here, sir.  [Duck blind control room]
#
#   Metadata
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# Saved cleaned file to: /home/sagemaker-user/trekBERT/Movies.csv/cleaned_cleaned_Star_Trek_Insurrection_Script.csv
# All files processed.

# %%
# !pwd
# Out:
# /home/sagemaker-user/trekBERT
