# %%
# pip install transformers[torch]

# %%
pip install --user datasets
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.11/site-packages (from datasets) (0.3.9)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.11/site-packages (from datasets) (0.70.17)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.11/site-packages (from fsspec[http]>=2021.05.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.28.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from datasets) (24.2)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.17.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp->datasets) (0.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import pandas as pd
import numpy as np
from transformers import AutoModelForMaskedLM, AutoTokenizer, Trainer, TrainingArguments, DataCollatorForLanguageModeling
from datasets import Dataset

# %% [markdown]
# ### 1. Identify Your Domain-Specific Dataset
# - Choose a dataset related to a particular domain (e.g., legal, medical, finance, science, etc.).
# - Ensure that the dataset contains enough textual data to be useful for training an MLM but not so much that you can't process it (may need to be some trial and error).

# %%
df = pd.read_csv('combined_cleaned_scripts.csv')

# %%
#TODO: do some nlp clean up on it
df.head()
# Out:
#    Scene_ID    Character                                           Dialogue  \
# 0       0.0  Star Trek V                                 The Final Frontier
# 1       0.0        SYBOK  I thought weapons were forbidden on this plane...
# 2       0.0        J'ONN                                   It's all I have.
# 3       0.0        SYBOK                               Your pain runs deep.
# 4       0.0        J'ONN                       What do you know of my pain?
#
#   Scene_Description                                           Metadata
# 0               NaN                                                NaN
# 1               NaN                     "The Planet of Galactic Peace"
# 2               NaN  (out of a dust storm a horseman approaches an ...
# 3               NaN                                                NaN
# 4               NaN                                                NaN

# %% [markdown]
# #### **Converting a Pandas DataFrame to a Hugging Face Dataset**
# The following line of code converts a Pandas DataFrame into a Hugging Face `Dataset`,
# which is optimized for use in HF training pipeline.

# %%
##use Dataset from HF to make training easier later
dataset = Dataset.from_pandas(pd.DataFrame({"text": df["Dialogue"].tolist()}))
##alternate datatypes
# Dataset.from_dict()
# Dataset.from_list()

# %%
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 7404
# })

# %% [markdown]
# ### 3. Load Model

# %%
##load models
model_name = "distilbert-base-uncased" #
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %% [markdown]
# #### **Converting a Pandas DataFrame to a Hugging Face Dataset**
# The below code applies a tokenization function to an entire dataset using Hugging Face's Dataset.map() function. There are two parts: <br>
# **The tokenize_function tokenizes text data using a Hugging Face tokenizer**
# * Truncation (truncation=True) → Ensures long texts are cut off at 512 tokens (BERT’s max length).
# * Padding (padding=True) → Ensures shorter texts are padded to 512 tokens.
# * Max Length (max_length=512) → Defines the maximum token limit per input.
#   <br>
#
# **dataset.map applies the function to the entire dataset**
#
# * Lambda Function (lambda x: tokenize_function(x, tokenizer))
# * Converts dataset.map() into a format that passes tokenizer into tokenize_function().
# batched=True → Optimizes Processing
#
# * Instead of processing one row at a time, it processes multiple rows at once, which is faster.

# %%
def tokenize_function(examples, tokenizer):
    """Tokenizes input text for MLM fine-tuning."""
    return tokenizer(examples["text"], truncation=True, padding=True, max_length=512)

# %%
##tokenize the dataset
#The .map() tokenization only prepares the dataset—but does not return PyTorch tensors.
tokenized_datasets = dataset.map(lambda x: tokenize_function(x, tokenizer), batched=True)
# Out:
# Parameter 'function'=<function <lambda> at 0x7f9709bc7380> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/8 [00:00<?, ?ba/s]

# %% [markdown]
# #### **Using HF Data Collator**
# * A utility from Hugging Face's transformers library that helps prepare data batches for training models like BERT, RoBERTa, and DistilBERT.
# * It automatically masks words in the input so that the model can learn to predict the missing words.

# %%
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=True,
    mlm_probability=0.3
)

# %%
def compute_perplexity(model, tokenizer, dataset, data_collator):
    """
    Computes the perplexity of a dataset using a masked language model.

    Parameters:
    - model: The pre-trained language model (e.g., BERT, DistilBERT).
    - tokenizer: The tokenizer corresponding to the model.
    - dataset: A dictionary containing a list of text samples under the "text" key.
    - data_collator: A collator that applies dynamic token masking for MLM training.

    Returns:
    - float: The computed perplexity value.
    """

    # Ensure model is in evaluation mode (prevents gradient updates)
    model.eval()

    # List to store loss values for each sample
    losses = []

    # Iterate over each text sample in the dataset
    for example in dataset["text"]:

        # Convert the text input into tokenized format
        # `return_tensors="pt"` returns tensors for PyTorch
        # `truncation=True` ensures long texts are truncated to max length
        # `padding=True` ensures consistent input size
        inputs = tokenizer(example, return_tensors="pt", truncation=True, padding=True)

        # Error handlind:
        # Check if `input_ids` tensor is empty (can happen for blank inputs)
        if inputs["input_ids"].nelement() == 0:
            print(f"Skipping empty input: {example}")
            continue

        # Apply masking using the data collator
        # The collator takes care of randomly masking tokens in the batch
        masked_batch = data_collator([{"input_ids": inputs["input_ids"].squeeze(0)}])

        # Move the masked batch tensors to the model's device (GPU if available)
        masked_batch = {k: v.to(model.device) for k, v in masked_batch.items()}

        # Disable gradient computation to save memory and improve speed
        with torch.no_grad():
            # Forward pass: compute predictions and loss
            outputs = model(**masked_batch)

            # Extract loss value from the model output
            loss = outputs.loss.item()

            # Debugging: Check if loss is NaN or Inf (should not happen)
            if np.isnan(loss) or np.isinf(loss):
                print(f"Skipping invalid loss for input: {example}")
                continue  # Skip this sample

            # Store valid loss values for later averaging
            losses.append(loss)

    # Handle case where all samples were skipped (to prevent NaN output)
    if not losses:
        return np.nan  # Return NaN if no valid losses were recorded

    # Compute perplexity:
    # Perplexity = exp(mean_loss)  (Lower perplexity means better language modeling)
    return np.exp(np.mean(losses))

# %%
perplexity_original = compute_perplexity(model, tokenizer, dataset, data_collator)
print(f"Baseline Perplexity: {perplexity_original:.2f}")
# Out:
# Skipping invalid loss for input: The Final Frontier
# Skipping invalid loss for input: Your pain runs deep.
# Skipping invalid loss for input: The power was within you.
# Skipping invalid loss for input: But how?
# Skipping invalid loss for input: You're a Vulcan!
# Skipping invalid loss for input: Uhura, I thought you were on leave?
# Skipping invalid loss for input: I don't believe this. Commander Sulu here.
# Skipping invalid loss for input: And?
# Skipping invalid loss for input: Ah.
# Skipping invalid loss for input: Captain?
# Skipping invalid loss for input: Jim?
# Skipping invalid loss for input: Are you sure about that?
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: You caught me on my way to the shower.
# Skipping invalid loss for input: The feeling's mutual. Engine room.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Good morning, Captain.
# Skipping invalid loss for input: Ah, this must be the hostage tape.
# Skipping invalid loss for input: Fascinating.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: A Federation starship.
# Skipping invalid loss for input: We don't have one point two hours.
# Skipping invalid loss for input: Spock.
# Skipping invalid loss for input: Yes, Captain?
# Skipping invalid loss for input: Roger, coming in.
# Skipping invalid loss for input: Who are you?
# Skipping invalid loss for input: Raise shields.
# Skipping invalid loss for input: Manually?
# Skipping invalid loss for input: Dammit. God dammit, Spock!
# Skipping invalid loss for input: You see?
# Skipping invalid loss for input: I don't understand.
# Skipping invalid loss for input: You could've warned me.
# Skipping invalid loss for input: Is what possible?
# Skipping invalid loss for input: Stand Back!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Get Mister Scott to sick bay.
# Skipping invalid loss for input: We're not splitting up.
# Skipping invalid loss for input: He's not?
# Skipping invalid loss for input: Leonard.
# Skipping invalid loss for input: Leonard.
# Skipping invalid loss for input: You're a doctor.
# Skipping invalid loss for input: No.
# Skipping invalid loss for input: No! I loved my father. I released him!
# Skipping invalid loss for input: What is this?
# Skipping invalid loss for input: Spock?
# Skipping invalid loss for input: Now learn something about yourself.
# Skipping invalid loss for input: Spock?
# Skipping invalid loss for input: About the ship.
# Skipping invalid loss for input: The land.
# Skipping invalid loss for input: The sky.
# Skipping invalid loss for input: With a starship!
# Skipping invalid loss for input: You doubt me?
# Skipping invalid loss for input: Do you doubt me?
# Skipping invalid loss for input: The ship.
# Skipping invalid loss for input: Mister Scott.
# Skipping invalid loss for input: Spock!
# Skipping invalid loss for input: Umm.
# Skipping invalid loss for input: Cosmic thoughts, gentlemen?
# Skipping invalid loss for input: First Contact
# Skipping invalid loss for input: Engage.
# Skipping invalid loss for input: Channel open.
# Skipping invalid loss for input: Fire.
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: I can hear them.
# Skipping invalid loss for input: Tough little ship.
# Skipping invalid loss for input: Little?
# Skipping invalid loss for input: You do remember how to fire phasers?
# Skipping invalid loss for input: Life signs?
# Skipping invalid loss for input: What is that?
# Skipping invalid loss for input: Captain!
# Skipping invalid loss for input: April fourth, two thousand sixtythree.
# Skipping invalid loss for input: April fourth?
# Skipping invalid loss for input: Precisely.
# Skipping invalid loss for input: How much damage, Lieutenant?
# Skipping invalid loss for input: Bullshit!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: It should be, sir.
# Skipping invalid loss for input: To the Phoenix. ...May she rest in peace.
# Skipping invalid loss for input: You are.
# Skipping invalid loss for input: Are you all right?
# Skipping invalid loss for input: Captain!
# Skipping invalid loss for input: Data!
# Skipping invalid loss for input: Here!
# Skipping invalid loss for input: Calm down!
# Skipping invalid loss for input: That's right.
# Skipping invalid loss for input: That's our ship. The Enterprise.
# Skipping invalid loss for input: What is this?
# Skipping invalid loss for input: Lily.
# Skipping invalid loss for input: There's no glass.
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Are you ready?
# Skipping invalid loss for input: Who are you?
# Skipping invalid loss for input: I am the Borg.
# Skipping invalid loss for input: I bring order to chaos.
# Skipping invalid loss for input: An interesting, if cryptic response.
# Skipping invalid loss for input: Heh, heh, heh.
# Skipping invalid loss for input: Is there another way around?
# Skipping invalid loss for input: What the hell are you doing?
# Skipping invalid loss for input: singing 'Moonlight Becomes You'
# Skipping invalid loss for input: No offence.
# Skipping invalid loss for input: Hey!
# Skipping invalid loss for input: Doctor!
# Skipping invalid loss for input: Yeah.
# Skipping invalid loss for input: Reg!
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Excuse me.
# Skipping invalid loss for input: Commander?
# Skipping invalid loss for input: Interplexing?
# Skipping invalid loss for input: Far too long.
# Skipping invalid loss for input: Doctor!
# Skipping invalid loss for input: Hawk!
# Skipping invalid loss for input: And you know, Doctor...
# Skipping invalid loss for input: Sir?
# Skipping invalid loss for input: No!
# Skipping invalid loss for input: Your objection is noted.
# Skipping invalid loss for input: Get off my bridge.
# Skipping invalid loss for input: Get out!
# Skipping invalid loss for input: Liar!
# Skipping invalid loss for input: No! ...No!
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Main bus.
# Skipping invalid loss for input: Data.
# Skipping invalid loss for input: Always am.
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Seventeen...
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Fifteen...
# Skipping invalid loss for input: What is it?
# Skipping invalid loss for input: Now enter the encryption codes and give me computer control.
# Skipping invalid loss for input: Engage.
# Skipping invalid loss for input: It's so small.
# Skipping invalid loss for input: She was unique.
# Skipping invalid loss for input: Report.
# Skipping invalid loss for input: Yes sir.
# Skipping invalid loss for input: Twelve years?
# Skipping invalid loss for input: Absolutely.
# Skipping invalid loss for input: I hope so.
# Skipping invalid loss for input: No.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Scotty?
# Skipping invalid loss for input: What the hell.
# Skipping invalid loss for input: Report!
# Skipping invalid loss for input: I have no idea.
# Skipping invalid loss for input: I thought you might.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Where?
# Skipping invalid loss for input: Aye.
# Skipping invalid loss for input: Thank you, sir.
# Skipping invalid loss for input: Fun?
# Skipping invalid loss for input: Fun.
# Skipping invalid loss for input: Look alive there!
# Skipping invalid loss for input: Survivors?
# Skipping invalid loss for input: Sir?
# Skipping invalid loss for input: Make it so. Just do it!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: More?
# Skipping invalid loss for input: I do not know.
# Skipping invalid loss for input: You get what?
# Skipping invalid loss for input: No.
# Skipping invalid loss for input: Ren? Oh, your nephew.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: And then you were beamed away from there.
# Skipping invalid loss for input: Data?
# Skipping invalid loss for input: What do you mean?
# Skipping invalid loss for input: Population?
# Skipping invalid loss for input: Worf here, sir.
# Skipping invalid loss for input: Did you get anything from the human?
# Skipping invalid loss for input: On screen.
# Skipping invalid loss for input: Me sir.
# Skipping invalid loss for input: The Nexus?
# Skipping invalid loss for input: Finally!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Farrell!
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: We love you father.
# Skipping invalid loss for input: Were you scared?
# Skipping invalid loss for input: This is the Nexus?
# Skipping invalid loss for input: Beautiful day.
# Skipping invalid loss for input: Aha.
# Skipping invalid loss for input: Better?
# Skipping invalid loss for input: Antonia?
# Skipping invalid loss for input: That's right.
# Skipping invalid loss for input: Good luck, Captain.
# Skipping invalid loss for input: Insurrection
# Skipping invalid loss for input: Alert, area twelve!
# Skipping invalid loss for input: Report.
# Skipping invalid loss for input: Over there!
# Skipping invalid loss for input: Say the greeting again.
# Skipping invalid loss for input: Go ahead, Ensign.
# Skipping invalid loss for input: Captain.
# Skipping invalid loss for input: Captain.
# Skipping invalid loss for input: Worf!
# Skipping invalid loss for input: Raise shields.
# Skipping invalid loss for input: Visual contact!
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Understood.
# Skipping invalid loss for input: Make it so.
# Skipping invalid loss for input: Beam him out!
# Skipping invalid loss for input: 'and his heart should glow.'
# Skipping invalid loss for input: We must stabilise the dampening fields.
# Skipping invalid loss for input: Engaging stabilisers.
# Skipping invalid loss for input: Now, Mister Worf!
# Skipping invalid loss for input: I never kissed you with a beard before.
# Skipping invalid loss for input: How were damaged?
# Skipping invalid loss for input: Failsafe?
# Skipping invalid loss for input: 'his nose should pant and his lip should curl...'
# Skipping invalid loss for input: Bridge to Riker.
# Skipping invalid loss for input: Doing what?
# Skipping invalid loss for input: Dougherty out.
# Skipping invalid loss for input: No.
# Skipping invalid loss for input: I am.
# Skipping invalid loss for input: Gorch?
# Skipping invalid loss for input: And our people?
# Skipping invalid loss for input: But not you?
# Skipping invalid loss for input: There are days!
# Skipping invalid loss for input: Will it?
# Skipping invalid loss for input: A perfect moment?
# Skipping invalid loss for input: For someone so young.
# Skipping invalid loss for input: Recommendations?
# Skipping invalid loss for input: Really?
# Skipping invalid loss for input: Really.
# Skipping invalid loss for input: Adapt?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: I'll be in engineering.
# Skipping invalid loss for input: What's inside that nebula cluster?
# Skipping invalid loss for input: Options?
# Skipping invalid loss for input: Bring them out!
# Skipping invalid loss for input: I'm losing her.
# Skipping invalid loss for input: It is not over.
# Skipping invalid loss for input: Yes sir.
# Skipping invalid loss for input: Initiate separation protocols.
# Skipping invalid loss for input: Separation in three minutes.
# Skipping invalid loss for input: Exactly as the simulations predicted.
# Skipping invalid loss for input: We're approaching the collector.
# Skipping invalid loss for input: 09
# Skipping invalid loss for input: Captain!
# Skipping invalid loss for input: 58 and he begins to work on it
# Skipping invalid loss for input: Target their ventral engines and life support. Set a collision course.
# Skipping invalid loss for input: Stop!
# Skipping invalid loss for input: 09
# Skipping invalid loss for input: Ask them.
# Skipping invalid loss for input: Bye.
# Skipping invalid loss for input: Good advice.
# Skipping invalid loss for input: Yes sir.
# Skipping invalid loss for input: Data!
# Skipping invalid loss for input: Sir?
# Skipping invalid loss for input: Yes sir.
# Skipping invalid loss for input: Theories?
# Skipping invalid loss for input: Just what I was afraid of.
# Skipping invalid loss for input: Very astute!
# Skipping invalid loss for input: Why?
# Skipping invalid loss for input: Because...
# Skipping invalid loss for input: Data.
# Skipping invalid loss for input: I am ...B4.
# Skipping invalid loss for input: Do you remember anything of your life before you were on the planet?
# Skipping invalid loss for input: You are me.
# Skipping invalid loss for input: Acknowledged.
# Skipping invalid loss for input: Understood.
# Skipping invalid loss for input: Romulus?
# Skipping invalid loss for input: What have you learned about Shinzon?
# Skipping invalid loss for input: Yes, Doctor Soong.
# Skipping invalid loss for input: Captain? ...No.
# Skipping invalid loss for input: Captain.
# Skipping invalid loss for input: Praetor?
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: Why?
# Skipping invalid loss for input: Do I serve you?
# Skipping invalid loss for input: As had I.
# Skipping invalid loss for input: Source?
# Skipping invalid loss for input: ...Oh yes.
# Skipping invalid loss for input: Go ahead, Data.
# Skipping invalid loss for input: On my way.
# Skipping invalid loss for input: Feel my lips.
# Skipping invalid loss for input: This isn't real!
# Skipping invalid loss for input: No!
# Skipping invalid loss for input: Hello, Jean Luc.
# Skipping invalid loss for input: Where?
# Skipping invalid loss for input: Good work.
# Skipping invalid loss for input: Go!
# Skipping invalid loss for input: Tractor beam, now!
# Skipping invalid loss for input: Why?
# Skipping invalid loss for input: Why?
# Skipping invalid loss for input: How long is that?
# Skipping invalid loss for input: How can you be certain?
# Skipping invalid loss for input: How long?
# Skipping invalid loss for input: Sir?
# Skipping invalid loss for input: Of you, sir?
# Skipping invalid loss for input: Report.
# Skipping invalid loss for input: Yes you can!
# Skipping invalid loss for input: We are being hailed.
# Skipping invalid loss for input: On screen.
# Skipping invalid loss for input: ...Not yet.
# Skipping invalid loss for input: He's resisting me.
# Skipping invalid loss for input: No!
# Skipping invalid loss for input: Number One.
# Skipping invalid loss for input: Let's go.
# Skipping invalid loss for input: Security detail to deck twentynine.
# Skipping invalid loss for input: Medical team to the bridge.
# Skipping invalid loss for input: Report.
# Skipping invalid loss for input: Goodbye.
# Skipping invalid loss for input: Captain?
# Skipping invalid loss for input: Captain, we're being hailed.
# Skipping invalid loss for input: Thank you, Commander.
# Skipping invalid loss for input: Data.
# Skipping invalid loss for input: Come. ...Will!
# Skipping invalid loss for input: Anything.
# Skipping invalid loss for input: Heading?
# Skipping invalid loss for input: Admiral.
# Skipping invalid loss for input: Take me over, please.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Bridge.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Yeah.
# Skipping invalid loss for input: a scream
# Skipping invalid loss for input: External view!
# Skipping invalid loss for input: Ellen.
# Skipping invalid loss for input: Maneuvering thrusters, sir.
# Skipping invalid loss for input: Viewer ahead.
# Skipping invalid loss for input: slowly, distorted Twenty seconds.
# Skipping invalid loss for input: Helm control restored, sir.
# Skipping invalid loss for input: Position report, Navigator?
# Skipping invalid loss for input: Granted.
# Skipping invalid loss for input: No.
# Skipping invalid loss for input: Make your point, Doctor.
# Skipping invalid loss for input: For what purpose?
# Skipping invalid loss for input: Is there anything further?
# Skipping invalid loss for input: Permission to come aboard, sir?
# Skipping invalid loss for input: All decks and divisions confirm, status red.
# Skipping invalid loss for input: Negative, We'll take no provocative action.
# Skipping invalid loss for input: I stand corrected.
# Skipping invalid loss for input: Medic.
# Skipping invalid loss for input: Thank you.
# Skipping invalid loss for input: Tactical plot on viewer.
# Skipping invalid loss for input: Recommend we proceed, Captain.
# Skipping invalid loss for input: Mister Decker?
# Skipping invalid loss for input: Five hundred metres?
# Skipping invalid loss for input: Viewer astern.
# Skipping invalid loss for input: Hold relative position here.
# Skipping invalid loss for input: Absolutely I will not interfere.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Scotty, drive systems should be free now.
# Skipping invalid loss for input: Commander?
# Skipping invalid loss for input: Viewer ahead.
# Skipping invalid loss for input: Thrusters ahead one third.
# Skipping invalid loss for input: To find the Creator.
# Skipping invalid loss for input: Fascinating. Not 'Deckerunit'? ...Gentlemen.
# Skipping invalid loss for input: Will.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Ilia.
# Skipping invalid loss for input: Now scanning pons area. Spinal nerve fiber connection.
# Skipping invalid loss for input: Spock?
# Skipping invalid loss for input: Radio?
# Skipping invalid loss for input: Why?
# Skipping invalid loss for input: Why?
# Skipping invalid loss for input: Twentyseven minutes. Mark.
# Skipping invalid loss for input: When, sir?
# Skipping invalid loss for input: On my command.
# Skipping invalid loss for input: Engineering, show me your readings.
# Skipping invalid loss for input: Not for us?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Captain.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Yes sir.
# Skipping invalid loss for input: in Klingonese You will be remembered with honour. ...Fire.
# Skipping invalid loss for input: Systems locked.
# Skipping invalid loss for input: Enterprise confirms.
# Skipping invalid loss for input: Would you look at that?
# Skipping invalid loss for input: I'm afraid that won't be necessary.
# Skipping invalid loss for input: That is out of the question.
# Skipping invalid loss for input: Speak.
# Skipping invalid loss for input: Share this with no one.
# Skipping invalid loss for input: Fascinating.
# Skipping invalid loss for input: Metallic mass.
# Skipping invalid loss for input: What is it?
# Skipping invalid loss for input: Why don't we beam it up?
# Skipping invalid loss for input: Or who.
# Skipping invalid loss for input: Yes, I was.
# Skipping invalid loss for input: Then, how was...
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: ...or the one.
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: Go.
# Skipping invalid loss for input: He'll die!
# Skipping invalid loss for input: Go.
# Skipping invalid loss for input: You're not going in there!
# Skipping invalid loss for input: Remember!
# Skipping invalid loss for input: Yours?
# Skipping invalid loss for input: Thanks for the drink.
# Skipping invalid loss for input: Long time, Doc.
# Skipping invalid loss for input: Got it.
# Skipping invalid loss for input: To your planet, welcome.
# Skipping invalid loss for input: Genesis!
# Skipping invalid loss for input: Federation Security, sir.
# Skipping invalid loss for input: With the prisoner.
# Skipping invalid loss for input: Uuhh! yawns
# Skipping invalid loss for input: Yes sir.
# Skipping invalid loss for input: Up your shaft.
# Skipping invalid loss for input: Understood. All stations clear.
# Skipping invalid loss for input: Okay! Uh...
# Skipping invalid loss for input: What course please, Admiral?
# Skipping invalid loss for input: Cleared, sir.
# Skipping invalid loss for input: Onequarter impulse.
# Skipping invalid loss for input: Yellow Alert!
# Skipping invalid loss for input: And now, Mister Scott.
# Skipping invalid loss for input: Full impulse power!
# Skipping invalid loss for input: Aye sir. Warp drive standing by!
# Skipping invalid loss for input: Execute!
# Skipping invalid loss for input: Request permission to beam aboard immediately.
# Skipping invalid loss for input: Captain, what is happening?
# Skipping invalid loss for input: Very good.
# Skipping invalid loss for input: They are.
# Skipping invalid loss for input: Response?
# Skipping invalid loss for input: in Vulcan So it has come.
# Skipping invalid loss for input: Vessel entering sector.
# Skipping invalid loss for input: in Klingonese Battle alert.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Fire!
# Skipping invalid loss for input: Ready to fire emergency tube.
# Skipping invalid loss for input: Is ...David with you?
# Skipping invalid loss for input: David, I don't understand.
# Skipping invalid loss for input: All set?
# Skipping invalid loss for input: You should take the Vulcan, too.
# Skipping invalid loss for input: Genesis, I want it.
# Skipping invalid loss for input: Kirk!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Wait! You said you would kill me!
# Skipping invalid loss for input: I lied.
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Are you kidding?
# Skipping invalid loss for input: Captain Kirk?
# Skipping invalid loss for input: Me?
# Skipping invalid loss for input: They are dying.
# Skipping invalid loss for input: All lines cleared.
# Skipping invalid loss for input: Hm. Hm.
# Skipping invalid loss for input: Jim?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: I've never been this close.
# Skipping invalid loss for input: I shall look forward to that.
# Skipping invalid loss for input: Energise.
# Skipping invalid loss for input: Chancellor.
# Skipping invalid loss for input: Chancellor!
# Skipping invalid loss for input: No!
# Skipping invalid loss for input: No!
# Skipping invalid loss for input: Thank God.
# Skipping invalid loss for input: Terrible table manners.
# Skipping invalid loss for input: Ah, Captain.
# Skipping invalid loss for input: Captain, they're coming about!
# Skipping invalid loss for input: Shields up, Captain?
# Skipping invalid loss for input: Captain?
# Skipping invalid loss for input: We surrender.
# Skipping invalid loss for input: Follow me.
# Skipping invalid loss for input: What happened?
# Skipping invalid loss for input: He's killing him!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Nevertheless.
# Skipping invalid loss for input: And?
# Skipping invalid loss for input: Barely.
# Skipping invalid loss for input: Objection!
# Skipping invalid loss for input: No. You were incompetent!
# Skipping invalid loss for input: Sustained.
# Skipping invalid loss for input: Continue.
# Skipping invalid loss for input: I cannot deny it.
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: Objection!
# Skipping invalid loss for input: There was an enormous neutron energy surge.
# Skipping invalid loss for input: A BirdofPrey?
# Skipping invalid loss for input: Cloaked?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: What are we looking for, sir?
# Skipping invalid loss for input: Lieutenant?
# Skipping invalid loss for input: And your coat.
# Skipping invalid loss for input: Any progress?
# Skipping invalid loss for input: Why not simply vaporise them?
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: Get in.
# Skipping invalid loss for input: Surprise!
# Skipping invalid loss for input: I like it here.
# Skipping invalid loss for input: Kill him! He's the one!
# Skipping invalid loss for input: No witnesses!
# Skipping invalid loss for input: Absolutely not!
# Skipping invalid loss for input: Come on!
# Skipping invalid loss for input: It would set off the alarm.
# Skipping invalid loss for input: Klingons and Federation members conspiring together.
# Skipping invalid loss for input: Who else?
# Skipping invalid loss for input: She does not know.
# Skipping invalid loss for input: Do you hear that?
# Skipping invalid loss for input: According to my information, today.
# Skipping invalid loss for input: Spock?
# Skipping invalid loss for input: Come on, I need you.
# Skipping invalid loss for input: Fascinating!
# Skipping invalid loss for input: The hull has been compromised.
# Skipping invalid loss for input: Sensor.
# Skipping invalid loss for input: Plate.
# Skipping invalid loss for input: Key.
# Skipping invalid loss for input: Fire!
# Skipping invalid loss for input: Fire!
# Skipping invalid loss for input: The word, sir?
# Skipping invalid loss for input: Uhura?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Sulu?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Nothing unreal exists.
# Skipping invalid loss for input: Here it comes now.
# Skipping invalid loss for input: Emergency Thrusters!
# Skipping invalid loss for input: No response, Captain!
# Skipping invalid loss for input: Emergency lights! ...Damage report!
# Skipping invalid loss for input: Systems report. Communications?
# Skipping invalid loss for input: Thank you.
# Skipping invalid loss for input: Permission granted.
# Skipping invalid loss for input: Station.
# Skipping invalid loss for input: Estimating Planet Earth, one point six hours present speed.
# Skipping invalid loss for input: You're joking!
# Skipping invalid loss for input: Admiral?
# Skipping invalid loss for input: What is it?
# Skipping invalid loss for input: To test my theory.
# Skipping invalid loss for input: Spock?
# Skipping invalid loss for input: Off the deep end, Mister Scott.
# Skipping invalid loss for input: On screen!
# Skipping invalid loss for input: Emergency reserve.
# Skipping invalid loss for input: What is our target in time?
# Skipping invalid loss for input: Aye sir?
# Skipping invalid loss for input: Put them on speakers.
# Skipping invalid loss for input: San Francisco. I was born there.
# Skipping invalid loss for input: Is that a lot?
# Skipping invalid loss for input: Simple logic.
# Skipping invalid loss for input: I know that!
# Skipping invalid loss for input: Why's that?
# Skipping invalid loss for input: How soon?
# Skipping invalid loss for input: You heard the lady!
# Skipping invalid loss for input: Why not?
# Skipping invalid loss for input: I see.
# Skipping invalid loss for input: Kirk here.
# Skipping invalid loss for input: How will playing cards help?
# Skipping invalid loss for input: Iowa.
# Skipping invalid loss for input: You guys like Italian?
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: With pleasure.
# Skipping invalid loss for input: Gregory!
# Skipping invalid loss for input: Of course.
# Skipping invalid loss for input: Hi!
# Skipping invalid loss for input: Please.
# Skipping invalid loss for input: Ah! Hello computer?
# Skipping invalid loss for input: Why right now?
# Skipping invalid loss for input: What's what?
# Skipping invalid loss for input: You want the details?
# Skipping invalid loss for input: When are those whales being released?
# Skipping invalid loss for input: Sure! Who gets the bad news?
# Skipping invalid loss for input: Name?
# Skipping invalid loss for input: My name?
# Skipping invalid loss for input: What do you think?
# Skipping invalid loss for input: Any luck?
# Skipping invalid loss for input: Is this real?
# Skipping invalid loss for input: What kind of spaceship is this?
# Skipping invalid loss for input: Mercy Hospital.
# Skipping invalid loss for input: He is not expected to survive.
# Skipping invalid loss for input: What's the matter with you?
# Skipping invalid loss for input: Bad day!
# Skipping invalid loss for input: Cramps.
# Skipping invalid loss for input: Hold it!
# Skipping invalid loss for input: No, no, no. All I need is the radio frequency to track them.
# Skipping invalid loss for input: Stabilise Energy Reserve! ...Report helm.
# Skipping invalid loss for input: Best shot?
# Skipping invalid loss for input: Guess, Spock. Your best guess.
# Skipping invalid loss for input: Bearing!
# Skipping invalid loss for input: What kind of ship is that?
# Skipping invalid loss for input: It is.
# Skipping invalid loss for input: Go on!
# Skipping invalid loss for input: Do you see them?
# Skipping invalid loss for input: Wait a minute! Where you going?
# Skipping invalid loss for input: They are my friends.
# Skipping invalid loss for input: A ship is a ship.
# Skipping invalid loss for input: Aye sir!
# Skipping invalid loss for input: Visual! ...Battle stations! Activate shields!
# Skipping invalid loss for input: Evasive action!
# Skipping invalid loss for input: Captain!
# Skipping invalid loss for input: Granted.
# Skipping invalid loss for input: Where are you off to, now?
# Skipping invalid loss for input: Home.
# Skipping invalid loss for input: Happy Birthday!
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Yes, Doctor.
# Skipping invalid loss for input: I hate inspections.
# Skipping invalid loss for input: Open the Air Lock.
# Skipping invalid loss for input: Running lights on.
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Captain's discretion.
# Skipping invalid loss for input: I have my orders.
# Skipping invalid loss for input: Well done, Commander.
# Skipping invalid loss for input: We learn by doing.
# Skipping invalid loss for input: Carol!
# Skipping invalid loss for input: So much for the little training cruise.
# Skipping invalid loss for input: Helmsman?
# Skipping invalid loss for input: No sir. No nothing!
# Skipping invalid loss for input: How far?
# Skipping invalid loss for input: Aye sir.
# Skipping invalid loss for input: Kirk, Admiral James T.
# Skipping invalid loss for input: Summary, please.
# Skipping invalid loss for input: What do you make of her?
# Skipping invalid loss for input: Let them eat static!
# Skipping invalid loss for input: Spock?
# Skipping invalid loss for input: Too late.
# Skipping invalid loss for input: Khan!
# Skipping invalid loss for input: Hurry!
# Skipping invalid loss for input: Admiral!
# Skipping invalid loss for input: Admiral!
# Skipping invalid loss for input: Damn!
# Skipping invalid loss for input: Admiral!
# Skipping invalid loss for input: Raise them.
# Skipping invalid loss for input: Fire! ...Fire!
# Skipping invalid loss for input: Aye.
# Skipping invalid loss for input: Stage Two of what?
# Skipping invalid loss for input: Jim!
# Skipping invalid loss for input: I...
# Skipping invalid loss for input: Oh, yes we can.
# Skipping invalid loss for input: Admiral?
# Skipping invalid loss for input: Can I cook or can't I?
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: By the book?
# Skipping invalid loss for input: Tactical!
# Skipping invalid loss for input: Fire!
# Skipping invalid loss for input: Joachim!
# Skipping invalid loss for input: Torpedoes ready, sir.
# Skipping invalid loss for input: What?
# Skipping invalid loss for input: No response, Admiral.
# Skipping invalid loss for input: Scotty!
# Skipping invalid loss for input: Two minutes, ten seconds.
# Skipping invalid loss for input: Time?
# Skipping invalid loss for input: Three minutes, thirty seconds.
# Skipping invalid loss for input: Distance from Reliant.
# Skipping invalid loss for input: We're not going to make it, are we?
# Skipping invalid loss for input: Better hurry!
# Skipping invalid loss for input: Spock!
# Skipping invalid loss for input: Yes.
# Skipping invalid loss for input: No!
# Skipping invalid loss for input: Come.
# Skipping invalid loss for input: Just words.
# Baseline Perplexity: 48.80
